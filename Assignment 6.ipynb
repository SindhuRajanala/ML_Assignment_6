# %%
import numpy as num
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn import preprocessing
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
import seaborn as sns
sns.set(style="white", color_codes=True)
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("CC GENERAL.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
dataframe = df.drop(["CUST_ID"],axis=1)
dataframe.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
dataframe.isnull().any()
# Out:
# BALANCE                             False
# BALANCE_FREQUENCY                   False
# PURCHASES                           False
# ONEOFF_PURCHASES                    False
# INSTALLMENTS_PURCHASES              False
# CASH_ADVANCE                        False
# PURCHASES_FREQUENCY                 False
# ONEOFF_PURCHASES_FREQUENCY          False
# PURCHASES_INSTALLMENTS_FREQUENCY    False
# CASH_ADVANCE_FREQUENCY              False
# CASH_ADVANCE_TRX                    False
# PURCHASES_TRX                       False
# CREDIT_LIMIT                         True
# PAYMENTS                            False
# MINIMUM_PAYMENTS                     True
# PRC_FULL_PAYMENT                    False
# TENURE                              False
# dtype: bool

# %%
dataframe.fillna(df.mean(), inplace=True)
dataframe.isnull().any()
# Out:
# BALANCE                             False
# BALANCE_FREQUENCY                   False
# PURCHASES                           False
# ONEOFF_PURCHASES                    False
# INSTALLMENTS_PURCHASES              False
# CASH_ADVANCE                        False
# PURCHASES_FREQUENCY                 False
# ONEOFF_PURCHASES_FREQUENCY          False
# PURCHASES_INSTALLMENTS_FREQUENCY    False
# CASH_ADVANCE_FREQUENCY              False
# CASH_ADVANCE_TRX                    False
# PURCHASES_TRX                       False
# CREDIT_LIMIT                        False
# PAYMENTS                            False
# MINIMUM_PAYMENTS                    False
# PRC_FULL_PAYMENT                    False
# TENURE                              False
# dtype: bool

# %%
dataframe.corr().style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_c472a_row0_col0, #T_c472a_row1_col1, #T_c472a_row2_col2, #T_c472a_row3_col3, #T_c472a_row4_col4, #T_c472a_row5_col5, #T_c472a_row6_col6, #T_c472a_row7_col7, #T_c472a_row8_col8, #T_c472a_row9_col9, #T_c472a_row10_col10, #T_c472a_row11_col11, #T_c472a_row12_col12, #T_c472a_row13_col13, #T_c472a_row14_col14, #T_c472a_row15_col15, #T_c472a_row16_col16 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_c472a_row0_col1, #T_c472a_row1_col9, #T_c472a_row2_col0, #T_c472a_row4_col3, #T_c472a_row4_col15, #T_c472a_row12_col13, #T_c472a_row13_col10 {
#   background-color: #fc9070;
#   color: #000000;
# }
# #T_c472a_row0_col2, #T_c472a_row15_col2, #T_c472a_row16_col8 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_c472a_row0_col3, #T_c472a_row0_col4, #T_c472a_row1_col2, #T_c472a_row1_col4, #T_c472a_row8_col7, #T_c472a_row11_col12, #T_c472a_row16_col15 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_c472a_row0_col5, #T_c472a_row8_col11, #T_c472a_row9_col0 {
#   background-color: #f34a36;
#   color: #f1f1f1;
# }
# #T_c472a_row0_col6, #T_c472a_row5_col1 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_c472a_row0_col7, #T_c472a_row3_col14 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_c472a_row0_col8 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_c472a_row0_col9, #T_c472a_row11_col3 {
#   background-color: #f34c37;
#   color: #f1f1f1;
# }
# #T_c472a_row0_col10 {
#   background-color: #fb6d4d;
#   color: #f1f1f1;
# }
# #T_c472a_row0_col11, #T_c472a_row7_col12 {
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_c472a_row0_col12 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_c472a_row0_col13, #T_c472a_row13_col8 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_c472a_row0_col14 {
#   background-color: #fb7555;
#   color: #f1f1f1;
# }
# #T_c472a_row0_col15, #T_c472a_row1_col13, #T_c472a_row6_col5, #T_c472a_row6_col9, #T_c472a_row6_col10, #T_c472a_row9_col2, #T_c472a_row9_col3, #T_c472a_row9_col4, #T_c472a_row9_col6, #T_c472a_row9_col7, #T_c472a_row9_col8, #T_c472a_row9_col11, #T_c472a_row9_col16, #T_c472a_row15_col0, #T_c472a_row15_col1, #T_c472a_row15_col12, #T_c472a_row15_col14 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_c472a_row0_col16, #T_c472a_row3_col1, #T_c472a_row6_col0, #T_c472a_row8_col16 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_c472a_row1_col0, #T_c472a_row13_col0 {
#   background-color: #fb6e4e;
#   color: #f1f1f1;
# }
# #T_c472a_row1_col3, #T_c472a_row3_col9, #T_c472a_row3_col16, #T_c472a_row6_col16, #T_c472a_row12_col1, #T_c472a_row16_col7, #T_c472a_row16_col14 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_c472a_row1_col5, #T_c472a_row11_col1, #T_c472a_row14_col10, #T_c472a_row15_col11 {
#   background-color: #fcb89e;
#   color: #000000;
# }
# #T_c472a_row1_col6 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# #T_c472a_row1_col7, #T_c472a_row1_col11, #T_c472a_row12_col15, #T_c472a_row16_col6 {
#   background-color: #fcb095;
#   color: #000000;
# }
# #T_c472a_row1_col8 {
#   background-color: #fc9c7d;
#   color: #000000;
# }
# #T_c472a_row1_col10 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_c472a_row1_col12, #T_c472a_row6_col13 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_c472a_row1_col14, #T_c472a_row1_col16, #T_c472a_row11_col16, #T_c472a_row16_col11 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_c472a_row1_col15, #T_c472a_row14_col16 {
#   background-color: #fdd3c1;
#   color: #000000;
# }
# #T_c472a_row2_col1, #T_c472a_row9_col14 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# #T_c472a_row2_col3, #T_c472a_row3_col2 {
#   background-color: #8c0912;
#   color: #f1f1f1;
# }
# #T_c472a_row2_col4, #T_c472a_row5_col9, #T_c472a_row10_col5 {
#   background-color: #d42121;
#   color: #f1f1f1;
# }
# #T_c472a_row2_col5, #T_c472a_row4_col9, #T_c472a_row11_col9, #T_c472a_row14_col15, #T_c472a_row16_col3, #T_c472a_row16_col9, #T_c472a_row16_col10 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_c472a_row2_col6, #T_c472a_row3_col13 {
#   background-color: #f75c41;
#   color: #f1f1f1;
# }
# #T_c472a_row2_col7, #T_c472a_row13_col5 {
#   background-color: #f6583e;
#   color: #f1f1f1;
# }
# #T_c472a_row2_col8, #T_c472a_row6_col2 {
#   background-color: #fb7757;
#   color: #f1f1f1;
# }
# #T_c472a_row2_col9 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_c472a_row2_col10, #T_c472a_row7_col10, #T_c472a_row10_col15 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_c472a_row2_col11, #T_c472a_row11_col2 {
#   background-color: #d21f20;
#   color: #f1f1f1;
# }
# #T_c472a_row2_col12, #T_c472a_row13_col7 {
#   background-color: #fca588;
#   color: #000000;
# }
# #T_c472a_row2_col13 {
#   background-color: #f44d38;
#   color: #f1f1f1;
# }
# #T_c472a_row2_col14, #T_c472a_row10_col13, #T_c472a_row11_col14 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_c472a_row2_col15, #T_c472a_row13_col9 {
#   background-color: #fc9272;
#   color: #000000;
# }
# #T_c472a_row2_col16, #T_c472a_row4_col16, #T_c472a_row8_col0, #T_c472a_row8_col3, #T_c472a_row16_col4 {
#   background-color: #fdccb8;
#   color: #000000;
# }
# #T_c472a_row3_col0, #T_c472a_row11_col15, #T_c472a_row12_col7 {
#   background-color: #fc9576;
#   color: #000000;
# }
# #T_c472a_row3_col4 {
#   background-color: #fc8767;
#   color: #f1f1f1;
# }
# #T_c472a_row3_col5, #T_c472a_row7_col9, #T_c472a_row8_col14 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_c472a_row3_col6 {
#   background-color: #fb7d5d;
#   color: #f1f1f1;
# }
# #T_c472a_row3_col7, #T_c472a_row4_col6 {
#   background-color: #f44f39;
#   color: #f1f1f1;
# }
# #T_c472a_row3_col8, #T_c472a_row14_col9 {
#   background-color: #fca78b;
#   color: #000000;
# }
# #T_c472a_row3_col10 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_c472a_row3_col11, #T_c472a_row13_col3 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_c472a_row3_col12, #T_c472a_row15_col4 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_c472a_row3_col15, #T_c472a_row4_col13, #T_c472a_row12_col4 {
#   background-color: #fc9d7f;
#   color: #000000;
# }
# #T_c472a_row4_col0, #T_c472a_row12_col9 {
#   background-color: #fc9e80;
#   color: #000000;
# }
# #T_c472a_row4_col1, #T_c472a_row14_col11 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_c472a_row4_col2, #T_c472a_row5_col10 {
#   background-color: #d52221;
#   color: #f1f1f1;
# }
# #T_c472a_row4_col5, #T_c472a_row14_col3, #T_c472a_row16_col5 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_c472a_row4_col7, #T_c472a_row6_col1, #T_c472a_row12_col10 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_c472a_row4_col8 {
#   background-color: #f0402f;
#   color: #f1f1f1;
# }
# #T_c472a_row4_col10, #T_c472a_row7_col5 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_c472a_row4_col11, #T_c472a_row11_col4, #T_c472a_row11_col6 {
#   background-color: #e22e27;
#   color: #f1f1f1;
# }
# #T_c472a_row4_col12, #T_c472a_row13_col16 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_c472a_row4_col14, #T_c472a_row14_col6 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_c472a_row5_col0, #T_c472a_row6_col11, #T_c472a_row7_col6 {
#   background-color: #f03d2d;
#   color: #f1f1f1;
# }
# #T_c472a_row5_col2, #T_c472a_row5_col4 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_c472a_row5_col3, #T_c472a_row5_col11, #T_c472a_row10_col2, #T_c472a_row15_col13 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_c472a_row5_col6, #T_c472a_row14_col7, #T_c472a_row14_col12 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_c472a_row5_col7, #T_c472a_row8_col13 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_c472a_row5_col8, #T_c472a_row6_col12 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_c472a_row5_col12, #T_c472a_row9_col1 {
#   background-color: #fcb79c;
#   color: #000000;
# }
# #T_c472a_row5_col13 {
#   background-color: #fc8565;
#   color: #f1f1f1;
# }
# #T_c472a_row5_col14, #T_c472a_row15_col7 {
#   background-color: #fcbda4;
#   color: #000000;
# }
# #T_c472a_row5_col15, #T_c472a_row6_col14, #T_c472a_row9_col13 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_c472a_row5_col16, #T_c472a_row10_col11 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_c472a_row6_col3, #T_c472a_row7_col8 {
#   background-color: #fca486;
#   color: #

# %%
x= dataframe.iloc[:,0:-1]
y= dataframe.iloc[:,-1]
scaler = preprocessing.StandardScaler()
scaler.fit(x)
X_scaled_array = scaler.transform(x)
X_scaled_dataframe = pd.DataFrame(X_scaled_array,columns = x.columns )

# %%
X_normalized = preprocessing.normalize(X_scaled_dataframe)
X_normalized = pd.DataFrame(X_normalized)

# %%
pca =PCA(n_components=2)
pc = pca.fit_transform(X_normalized)
pdf = pd.DataFrame(data = pc, columns = ['p1','p2'])
fdf = pd.concat([pdf,df[['TENURE']]],axis= 1)
fdf.head()
# Out:
#          p1        p2  TENURE
# 0 -0.488186 -0.677233      12
# 1 -0.517294  0.556075      12
# 2  0.334384  0.287313      12
# 3 -0.486616 -0.080780      12
# 4 -0.562175 -0.474770      12

# %%
plt.figure(figsize=(7,7))
plt.scatter(fdf['p1'],fdf['p2'],c=fdf['TENURE'],cmap='prism',s=5)
plt.xlabel('pc1')
plt.ylabel('pc2')
# Out:
# Text(0, 0.5, 'pc2')

# %%
ac = AgglomerativeClustering(n_clusters= 2)
plt.figure(figsize = (6,6))
plt.scatter(pdf['p1'],pdf['p2'],c=ac.fit_predict(pdf),cmap = 'rainbow')
plt.show()

# %%
ac1 = AgglomerativeClustering(n_clusters= 3)
plt.figure(figsize = (6,6))
plt.scatter(pdf['p1'],pdf['p2'],c=ac.fit_predict(pdf),cmap = 'rainbow')
plt.show()

# %%
ac2 = AgglomerativeClustering(n_clusters= 4)
plt.figure(figsize = (6,6))
plt.scatter(pdf['p1'],pdf['p2'],c=ac.fit_predict(pdf),cmap = 'rainbow')
plt.show()

# %%
ac3 = AgglomerativeClustering(n_clusters= 5)
plt.figure(figsize = (6,6))
plt.scatter(pdf['p1'],pdf['p2'],c=ac.fit_predict(pdf),cmap = 'rainbow')
plt.show()

# %%
k=[2,3,4,5]
silhouette_scores = []
silhouette_scores.append(silhouette_score(pdf,ac.fit_predict(pdf)))
silhouette_scores.append(silhouette_score(pdf,ac1.fit_predict(pdf)))
silhouette_scores.append(silhouette_score(pdf,ac2.fit_predict(pdf)))
silhouette_scores.append(silhouette_score(pdf,ac3.fit_predict(pdf)))
plt.bar(k, silhouette_scores)
plt.xlabel('Number of clusters', fontsize=20)
plt.ylabel('S(i)',fontsize=20)
plt.show()
